# %%
# %cd source
# Out:
# /home/karam/DataspellProjects/dsProject/Internship/th/thesaurus/source

# %%
from thesaurus import Thesaurus
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
obj = Thesaurus(lang='fra')
# Out:
# [nltk_data] Downloading package words to /home/karam/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/karam/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
text1 = obj.read_txt('../data/covid19.txt')
text2 = obj.read_txt('../data/descartes.txt')

# %%
# texts is the dictionary with all source texts that will be preprocessed
# texts = {'foreground name1': [source text1, source text2, ...], ...}
texts = dict()

# list of foreground names
# foreground_names = ['foreground name1', ...]
foreground_names = []

foreground_name1 = 'Covid 19'
texts[foreground_name1] = [text1]
foreground_names.append(foreground_name1)

foreground_name2 = 'Discours de la méthode, René Descartes'
texts[foreground_name2] = [text2]
foreground_names.append(foreground_name2)

# %%
# !python -m spacy download fr_core_news_md

# %%
MODEL_en = 'en_core_web_md-3.0.0/en_core_web_md/en_core_web_md-3.0.0'
MODEL_fr = 'fr_core_news_md'
obj.set_spacy_model(MODEL_fr)

# %%
# dictionary with the embeddings and tokens of each foreground unit
# processed_foregrounds = {'foreground_name1': {'embeds': embeddings, 'words': tokens}, ...}
processed_foregrounds = obj.process_foreground(foreground_names, texts)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.73s/it]
#  50%|█████     | 1/2 [00:01<00:01,  1.73s/it]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.20s/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.47s/it]

# %%
background_embeds, background_words = obj.import_background()

# %%
obj.set_som()

# %%
print("Go to https://nbviewer.org/github/DinarZayahov/thesaurus/blob/master/ThesaurusVisualization.ipynb to see the outputs of the notebook as the GitHub doesn't render dynamic output")
obj.show_map(background_embeds, background_words, foreground_names, processed_foregrounds)
# Out:
# Go to https://nbviewer.org/github/DinarZayahov/thesaurus/blob/master/ThesaurusVisualization.ipynb to see the outputs of the notebook as the GitHub doesn't render dynamic output
#   <div class="bk-root" id="7eef0afb-0189-4773-bc23-0dd7599c4976" data-root-id="1002"></div>

# %%
obj = Thesaurus(lang='deu')
# Out:
# Please choose one of the following languages: ['eng','fra']
# [nltk_data] Downloading package words to /home/karam/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/karam/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
text1 = obj.read_txt('../data/berlin.txt')
text2 = obj.read_txt('../data/machine.txt')

# %%
# texts is the dictionary with all source texts that will be preprocessed
# texts = {'foreground name1': [source text1, source text2, ...], ...}
texts = dict()

# list of foreground names
# foreground_names = ['foreground name1', ...]
foreground_names = []

foreground_name1 = 'Alfred Doblin. Berlin Alexanderplatz'
texts[foreground_name1] = [text1]
foreground_names.append(foreground_name1)

foreground_name2 = 'Maschinelles Lernen'
texts[foreground_name2] = [text2]
foreground_names.append(foreground_name2)

# %%
obj.set_spacy_model()

# %%
# dictionary with the embeddings and tokens of each foreground unit
# processed_foregrounds = {'foreground_name1': {'embeds': embeddings, 'words': tokens}, ...}
processed_foregrounds = obj.process_foreground(foreground_names, texts)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.83s/it]
#  50%|█████     | 1/2 [00:04<00:04,  4.83s/it]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:02<00:00,  2.88s/it]
# 100%|██████████| 2/2 [00:07<00:00,  3.86s/it]

# %%
background_embeds, background_words = obj.import_background()

# %%
obj.set_som()

# %%
print("Go to https://nbviewer.org/github/DinarZayahov/thesaurus/blob/master/ThesaurusVisualization.ipynb to see the outputs of the notebook as the GitHub doesn't render dynamic output")
obj.show_map(background_embeds, background_words, foreground_names, processed_foregrounds)
# Out:
# Go to https://nbviewer.org/github/DinarZayahov/thesaurus/blob/master/ThesaurusVisualization.ipynb to see the outputs of the notebook as the GitHub doesn't render dynamic output
#   <div class="bk-root" id="9884334b-61f7-44a6-969f-36c763a741b4" data-root-id="1002"></div>
