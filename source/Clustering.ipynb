# %%
from thesaurus import Thesaurus
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
import pickle
# Load as pickle
with open('../data/index_eng.pickle', 'rb') as f:
    data_pickle = pickle.load(f)
data_pickle
# Out:
# {'will': (66, 69),
#  'time': (61, 11),
#  'year': (6, 98),
#  'people': (99, 82),
#  'day': (90, 44),
#  'man': (19, 85),
#  'find': (4, 91),
#  'thing': (20, 59),
#  'woman': (83, 58),
#  'life': (70, 53),
#  'child': (0, 3),
#  'work': (1, 29),
#  'call': (57, 38),
#  'school': (8, 9),
#  'feel': (70, 54),
#  'state': (68, 98),
#  'family': (76, 94),
#  'leave': (45, 96),
#  'student': (6, 11),
#  'group': (41, 72),
#  'country': (7, 35),
#  'help': (3, 93),
#  'talk': (8, 21),
#  'turn': (72, 79),
#  'problem': (52, 47),
#  'start': (98, 88),
#  'hand': (57, 35),
#  'place': (61, 22),
#  'case': (59, 19),
#  'week': (87, 44),
#  'company': (56, 75),
#  'system': (6, 96),
#  'program': (25, 4),
#  'hear': (37, 58),
#  'question': (78, 30),
#  'play': (13, 9),
#  'government': (40, 98),
#  'number': (45, 63),
#  'move': (34, 73),
#  'night': (25, 92),
#  'live': (39, 51),
#  'point': (22, 26),
#  'hold': (14, 94),
#  'bring': (19, 57),
#  'happen': (89, 42),
#  'water': (86, 27),
#  'room': (20, 56),
#  'write': (54, 23),
#  'mother': (78, 94),
#  'area': (60, 22),
#  'money': (77, 7),
#  'story': (15, 27),
#  'fact': (18, 3),
#  'month': (40, 75),
#  'lot': (27, 9),
#  'study': (3, 79),
#  'book': (11, 28),
#  'eye': (72, 89),
#  'job': (1, 29),
#  'word': (34, 2),
#  'business': (56, 75),
#  'issue': (52, 47),
#  'side': (82, 40),
#  'kind': (53, 6),
#  'head': (37, 78),
#  'house': (80, 62),
#  'provide': (81, 71),
#  'service': (59, 16),
#  'friend': (51, 46),
#  'father': (80, 98),
#  'sit': (81, 63),
#  'power': (69, 56),
#  'hour': (99, 18),
#  'game': (41, 25),
#  'stand': (15, 93),
#  'lose': (21, 22),
#  'member': (44, 89),
#  'pay': (6, 62),
#  'law': (70, 69),
#  'meet': (99, 82),
#  'car': (64, 99),
#  'city': (3, 31),
#  'include': (36, 18),
#  'continue': (16, 12),
#  'set': (66, 20),
#  'community': (1, 33),
#  'president': (46, 14),
#  'learn': (19, 12),
#  'change': (88, 96),
#  'team': (0, 97),
#  'minute': (99, 17),
#  'idea': (9, 16),
#  'body': (19, 86),
#  'lead': (53, 42),
#  'understand': (73, 69),
#  'watch': (95, 90),
#  'follow': (38, 50),
#  'parent': (76, 94),
#  'face': (48, 27),
#  'create': (62, 44),
#  'speak': (9, 19),
#  'read': (47, 37),
#  'level': (45, 68),
#  'allow': (51, 92),
#  'add': (45, 92),
#  'office': (1, 26),
#  'spend': (77, 7),
#  'door': (88, 32),
#  'health': (46, 66),
#  'person': (19, 85),
#  'art': (13, 45),
#  'war': (36, 40),
#  'history': (14, 29),
#  'party': (76, 29),
#  'grow': (25, 35),
#  'result': (11, 82),
#  'open': (77, 61),
#  'morning': (53, 0),
#  'walk': (45, 51),
#  'reason': (74, 68),
#  'win': (8, 48),
#  'girl': (35, 48),
#  'guy': (46, 8),
#  'food': (36, 99),
#  'moment': (99, 16),
#  'air': (86, 27),
#  'teacher': (7, 11),
#  'force': (60, 58),
#  'offer': (11, 61),
#  'education': (8, 8),
#  'remember': (4, 36),
#  'foot': (41, 20),
#  'boy': (1, 10),
#  'age': (5, 7),
#  'policy': (47, 13),
#  'love': (71, 57),
#  'process': (7, 96),
#  'music': (34, 40),
#  'consider': (55, 62),
#  'appear': (98, 90),
#  'buy': (8, 59),
#  'wait': (10, 94),
#  'serve': (22, 79),
#  'market': (9, 51),
#  'die': (81, 17),
#  'send': (65, 26),
#  'expect': (80, 93),
#  'sense': (76, 67),
#  'build': (61, 45),
#  'stay': (13, 94),
#  'fall': (39, 74),
#  'nation': (63, 74),
#  'plan': (28, 89),
#  'cut': (72, 83),
#  'college': (5, 81),
#  'interest': (20, 22),
#  'death': (81, 17),
#  'experience': (7, 28),
#  'reach': (11, 82),
#  'kill': (59, 8),
#  'remain': (12, 94),
#  'class': (99, 73),
#  'control': (71, 11),
#  'raise': (50, 40),
#  'care': (87, 90),
#  'field': (15, 42),
#  'pass': (12, 65),
#  'sell': (5, 57),
#  'require': (40, 31),
#  'development': (0, 8),
#  'report': (33, 6),
#  'role': (38, 19),
#  'effort': (20, 24),
#  'decide': (29, 64),
#  'rate': (6, 59),
#  'heart': (71, 99),
#  'drug': (70, 18),
#  'leader': (57, 77),
#  'light': (58, 0),
#  'voice': (81, 1),
#  'wife': (82, 59),
#  'police': (63, 67),
#  'mind': (27, 88),
#  'pull': (86, 66),
#  'return': (69, 78),
#  'price': (6, 59),
#  'decision': (58, 63),
#  'explain': (21, 8),
#  'son': (2, 10),
#  'hope': (69, 52),
#  'develop': (0, 8),
#  'view': (98, 90),
#  'relationship': (13, 7),
#  'carry': (19, 57),
#  'town': (0, 33),
#  'road': (76, 83),
#  'drive': (80, 7),
#  'arm': (52, 34),
#  'break': (97, 9),
#  'difference': (40, 45),
#  'receive': (63, 26),
#  'building': (76, 38),
#  'action': (69, 56),
#  'model': (45, 21),
#  'join': (40, 11),
#  'season': (39, 74),
#  'society': (98, 3),
#  'tax': (41, 99),
#  'director': (6, 29),
#  'position': (61, 23),
#  'player': (19, 91),
#  'agree': (52, 94),
#  'record': (57, 24),
#  'pick': (31, 64),
#  'wear': (25, 42),
#  'paper': (45, 46),
#  'space': (94, 86),
#  'ground': (81, 38),
#  'form': (46, 93),
#  'support': (19, 66),
#  'event': (98, 14),
#  'official': (44, 97),
#  'matter': (18, 3),
#  'center': (13, 77),
#  'couple': (79, 56),
#  'site': (84, 34),
#  'project': (55, 44),
#  'hit': (94, 16),
#  'base': (81, 38),
#  'activity': (69, 56),
#  'star': (59, 1),
#  'table': (49, 21),
#  'court': (71, 67),
#  'produce': (25, 34),
#  'eat': (36, 97),
#  'teach': (6, 12),
#  'oil': (8, 74),
#  'situation': (37, 31),
#  'cost': (6, 59),
#  'industry': (89, 71),
#  'figure': (52, 31),
#  'street': (73, 84),
#  'image': (50, 31),
#  'phone': (90, 30),
#  'datum': (58, 14),
#  'cover': (52, 27),
#  'picture': (50, 31),
#  'practice': (14, 0),
#  'piece': (20, 86),
#  'land': (15, 46),
#  'describe': (36, 3),
#  'product': (4, 58),
#  'doctor': (10, 0),
#  'wall': (67, 77),
#  'patient': (33, 68),
#  'worker': (0, 30),
#  'news': (46, 42),
#  'test': (56, 68),
#  'movie': (94, 74),
#  'north': (91, 85),
#  'technology': (62, 90),
#  'catch': (44, 47),
#  'step': (37, 21),
#  'baby': (0, 3),
#  'computer': (38, 11),
#  'type': (8, 22),
#  'attention': (13, 13),
#  'draw': (49, 42),
#  'film': (94, 75),
#  'republican': (46, 13),
#  'organization': (4, 24),
#  'tree': (19, 40),
#  'source': (38, 34),
#  'choose': (30, 64),
#  'hair': (41, 80),
#  'century': (61, 12),
#  'evidence': (71, 34),
#  'window': (71, 48),
#  'listen': (37, 58),
#  'culture': (63, 64),
#  'chance': (92, 78),
#  'brother': (4, 13),
#  'energy': (46, 85),
#  'realize': (18, 3),
#  'period': (33, 23),
#  'course': (99, 73),
#  'summer': (54, 4),
#  'plant': (28, 31),
#  'opportunity': (21, 24),
#  'term': (36, 2),
#  'letter': (49, 95),
#  'condition': (37, 31),
#  'choice': (30, 64),
#  'rule': (55, 97),
#  'daughter': (51, 16),
#  'administration': (39, 99),
#  'south': (99, 34),
#  'husband': (81, 59),
#  'congress': (49, 15),
#  'floor': (43, 36),
#  'campaign': (43, 63),
#  'material': (61, 44),
#  'population': (43, 62),
#  'economy': (75, 18),
#  'hospital': (33, 68),
#  'church': (60, 28),
#  'close': (93, 75),
#  'risk': (95, 79),
#  'fire': (48, 80),
#  'future': (70, 52),
#  'involve': (38, 19),
#  'defense': (20, 43),
#  'behavior': (70, 55),
#  'increase': (50, 40),
#  'security': (64, 10),
#  'bank': (79, 12),
#  'west': (7, 35),
#  'sport': (58, 47),
#  'board': (95, 27),
#  'seek': (4, 91),
#  'subject': (16, 5),
#  'officer': (63, 67),
#  'rest': (86, 97),
#  'deal': (12, 52),
#  'performance': (78, 4),
#  'fight': (6, 66),
#  'throw': (86, 40),
#  'top': (47, 69),
#  'goal': (55, 46),
#  'second': (14, 32),
#  'bed': (22, 56),
#  'order': (60, 26),
#  'author': (10, 30),
#  'fill': (2, 10),
#  'represent': (48, 24),
#  'focus': (13, 13),
#  'drop': (78, 23),
#  'blood': (91, 57),
#  'agency': (6, 24),
#  'push': (18, 44),
#  'nature': (74, 59),
#  'color': (93, 14),
#  'store': (10, 54),
#  'reduce': (69, 11),
#  'sound': (38, 37),
#  'note': (38, 20),
#  'movement': (35, 74),
#  'enter': (35, 21),
#  'share': (75, 4),
#  'race': (0, 13),
#  'concern': (95, 54),
#  'series': (52, 92),
#  'language': (39, 1),
#  'response': (68, 61),
#  'rise': (22, 76),
#  'animal': (97, 51),
#  'factor': (63, 63),
#  'decade': (91, 70),
#  'article': (48, 45),
#  'shoot': (89, 1),
#  'east': (90, 90),
#  'save': (79, 7),
#  'artist': (51, 30),
#  'scene': (56, 22),
#  'stock': (54, 73),
#  'career': (15, 2),
#  'treatment': (47, 35),
#  'protect': (63, 8),
#  'approach': (28, 88),
#  'lie': (54, 65),
#  'size': (48, 38),
#  'dog': (98, 50),
#  'fund': (16, 79),
#  'occur': (88, 41),
#  'medium': (21, 16),
#  'sign': (48, 25),
#  'list': (49, 89),
#  'individual': (65, 95),
#  'quality': (0, 80),
#  'pressure': (60, 58),
#  'accept': (15, 20),
#  'answer': (69, 61),
#  'resource': (85, 32),
#  'identify': (42, 30),
#  'meeting': (99, 82),
#  'determine': (37, 3),
#  'prepare': (0, 53),
#  'disease': (86, 48),
#  'success': (12, 83),
#  'argue': (40, 42),
#  'recognize': (19, 11),
#  'cup': (33, 88),
#  'amount': (66, 10),
#  'ability': (4, 86),
#  'staff': (60, 21),
#  'indicate': (48, 25),
#  'character': (53, 43),
#  'growth': (5, 8),
#  'loss': (14, 16),
#  'degree': (6, 79),
#  'wonder': (53, 50),
#  'attack': (18, 42),
#  'region': (58, 23),
#  'television': (48, 42),
#  'box': (65, 47),
#  'training': (34, 64),
#  'trade': (10, 51),
#  'election': (50, 16),
#  'standard': (21, 6),
#  'message': (65, 15),
#  'fail': (47, 58),
#  'bill': (10, 65),
#  'arrive': (21, 78),
#  'analysis': (37, 5),
#  'benefit': (24, 1),
#  'sex': (38, 53),
#  'lawyer': (70, 67),
#  'glass': (71, 90),
#  'skill': (6, 93),
#  'sister': (51, 16),
#  'professor': (3, 79),
#  'operation': (59, 17),
#  'crime': (46, 52),
#  'stage': (56, 22),
#  'compare': (39, 44),
#  'authority': (68, 58),
#  'design': (13, 45),
#  'sort': (22, 79),
#  'knowledge': (49, 71),
#  'gun': (89, 1),
#  'station': (30, 66),
#  'strategy': (28, 90),
#  'discuss': (7, 21),
#  'truth': (16, 67),
#  'song': (33, 40),
#  'example': (31, 5),
#  'check': (56, 66),
#  'environment': (76, 61),
#  'leg': (42, 19),
#  'public': (40, 62),
#  'laugh': (45, 12),
#  'guess': (11, 10),
#  'executive': (6, 24),
#  'prove': (71, 34),
#  'rock': (82, 32),
#  'forget': (5, 35),
#  'claim': (65, 68),
#  'remove': (79, 48),
#  'manager': (4, 28),
#  'enjoy': (42, 6),
#  'network': (89, 28),
#  'science': (60, 59),
#  'memory': (3, 34),
#  'card': (32, 11),
#  'seat': (59, 88),
#  'cell': (45, 78),
#  'establish': (61, 39),
#  'trial': (67, 66),
#  'expert': (5, 12),
#  'spring': (53, 4),
#  'firm': (56, 75),
#  'democrat': (45, 16),
#  'radio': (47, 41),
#  'visit': (42, 52),
#  'management': (2, 27),
#  'avoid': (3, 3),
#  'imagine': (9, 16),
#  'ball': (57, 46),
#  'finish': (15, 76),
#  'theory': (9, 16),
#  'impact': (18, 1),
#  'respond': (68, 61),
#  'statement': (46, 90),
#  'maintain': (14, 95),
#  'charge': (7, 60),
#  'reveal': (98, 84),
#  'direction': (27, 89),
#  'weapon': (86, 4),
#  'employee': (0, 27),
#  'peace': (21, 99),
#  'pain': (69, 55),
#  'apply': (9, 96),
#  'measure': (19, 4),
#  'shake': (85, 64),
#  'fly': (19, 58),
#  'interview': (45, 40),
#  'manage': (2, 27),
#  'chair': (54, 27),
#  'fish': (90, 25),
#  'camera': (49, 30),
#  'structure': (1, 84),
#  'politics': (48, 16),
#  'bit': (23, 90),
#  'perform': (78, 3),
#  'weight': (99, 94),
#  'discover': (65, 4),
#  'candidate': (42, 64),
#  'production': (62, 45),
#  'treat': (41, 87),
#  'evening': (54, 2),
#  'trip': (43, 54),
#  'affect': (18, 1),
#  'conference': (99, 84),
#  'unit': (63, 22),
#  'style': (55, 80),
#  'adult': (5, 7),
#  'worry': (95, 54),
#  'mention': (46, 90),
#  'range': (11, 80),
#  'edge': (66, 45),
#  'writer': (55, 23),
#  'trouble': (73, 96),
#  'challenge': (43, 45),
#  'fear': (0, 50),
#  'shoulder': (35, 16),
#  'institution': (32, 71),
#  'sea': (98, 32),
#  'dream': (0, 99),
#  'bar': (92, 18),
#  'property': (54, 98),
#  'improve': (14, 98),
#  'stuff': (18, 60),
#  'detail': (56, 93),
#  'method': (7, 95),
#  'magazine': (45, 45),
#  'hotel': (75, 39),
#  'soldier': (88, 6),
#  'reflect': (55, 64),
#  'bag': (6, 37),
#  'heat': (22, 53),
#  'marriage': (82, 96),
#  'sing': (78, 1),
#  'purpose': (55, 44),
#  'surface': (83, 68),
#  'exist': (46, 92),
#  'pattern': (2, 85),
#  'skin': (56, 80),
#  'agent': (30, 1),
#  'owner': (7, 58),
#  'machine': (67, 24),
#  'gas': (46, 82),
#  'generation': (5, 7),
#  'address': (61, 21),
#  'cancer': (49, 1),
#  'item': (65, 93),
#  'reality': (16, 4),
#  'coach': (56, 45),
#  'yard': (10, 37),
#  'beat': (96, 11),
#  'violence': (88, 37),
#  'tend': (22, 85),
#  'investment': (56, 74),
#  'discussion': (56, 64),
#  'finger': (57, 35),
#  'garden': (18, 38),
#  'notice': (3, 19),
#  'collection': (26, 4),
#  'task': (55, 44),
#  'partner': (0, 94),
#  'kitchen': (36, 88),
#  'consumer': (7, 59),
#  'shot': (89, 1),
#  'budget': (76, 6),
#  'paint': (93, 14),
#  'scientist': (60, 59),
#  'agreement': (52, 94),
#  'mouth': (33, 96),
#  'capital': (38, 0),
#  'victim': (88, 40),
#  'newspaper': (45, 44),
#  'threat': (94, 80),
#  'responsibility': (71, 12),
#  'smile': (44, 13),
#  'attorney': (70, 67),
#  'score': (46, 62),
#  'account': (5, 62),
#  'audience': (46, 38),
#  'dinner': (43, 84),
#  'vote': (51, 17),
#  'relate': (8, 28),
#  'travel': (43, 54),
#  'debate': (39, 42),
#  'prevent': (4, 3),
#  'citizen': (66, 75),
#  'majority': (44, 61),
#  'bear': (30, 54),
#  'admit': (51, 94),
#  'assume': (3, 57),
#  'wind': (34, 58),
#  'mission': (55, 44),
#  'customer': (9, 59),
#  'suffer': (69, 55),
#  'speech': (9, 19),
#  'option': (29, 64),
#  'participant': (37, 17),
#  'forest': (23, 39),
#  'video': (96, 75),
#  'senate': (47, 14),
#  'reform': (93, 92),
#  'access': (87, 33),
#  'restaurant': (41, 84),
#  'judge': (71, 67),
#  'publish': (46, 46),
#  'relation': (13, 7),
#  'release': (40, 62),
#  'bird': (88, 53),
#  'labor': (1, 29),
#  'opinion': (56, 64),
#  'credit': (77, 15),
#  'corner': (75, 86),
#  'recall': (0, 23),
#  'version': (17, 96),
#  'stare': (22, 79),
#  'safety': (63, 9),
#  'neighborhood': (59, 22),
#  'troop': (88, 4),
#  'income': (75, 18),
#  'hurt': (85, 42),
#  'specie': (41, 27),
#  'track': (92, 34),
#  'strike': (54, 84),
#  'sky': (23, 75),
#  'freedom': (7, 46),
#  'plane': (18, 73),
#  'achieve': (12, 82),
#  'object': (30, 8),
#  'attitude': (69, 52),
#  'refer': (39, 35),
#  'client': (10, 60),
#  'concept': (8, 14),
#  'conduct': (14, 9),
#  'conversation': (8, 21),
#  'examine': (57, 15),
#  'touch': (93, 37),
#  'attend': (9, 33),
#  'variety': (20, 21),
#  'sleep': (77, 92),
#  'investigation': (60, 66),
#  'researcher': (55, 68),
#  'press': (45, 42),
#  'conflict': (5, 65),
#  'spirit': (63, 0),
#  'replace': (90, 99),
#  'encourage': (67, 28),
#  'argument': (39, 43),
#  'camp': (80, 33),
#  'brain': (52, 69),
#  'feature': (2, 85),
#  'afternoon': (53, 2),
#  'weekend': (54, 5),
#  'possibility': (93, 78),
#  'insurance': (57, 13),
#  'department': (2, 26),
#  'battle': (39, 40),
#  'crisis': (1, 67),
#  'complete': (14, 75),
#  'fan': (19, 85),
#  'stick': (70, 85),
#  'define': (36, 2),
#  'hole': (53, 58),
#  'element': (0, 80),
#  'status': (90, 73),
#  'vision': (72, 88),
#  'ship': (94, 24),
#  'stone': (83, 33),
#  'solution': (23, 0),
#  'scale': (48, 40),
#  'university': (3, 80),
#  'introduce': (98, 86),
#  'driver': (57, 18),
#  'attempt': (20, 24),
#  'park': (87, 29),
#  'spot': (60, 23),
#  'lack': (26, 11),
#  'ice': (71, 43),
#  'boat': (98, 27),
#  'drink': (74, 25),
#  'sun': (30, 34),
#  'distance': (73, 80),
#  'wood': (81, 37),
#  'truck': (59, 94),
#  'handle': (89, 61),
#  'mountain': (17, 44),
#  'survey': (95, 32),
#  'tradition': (11, 26),
#  'winter': (71, 40),
#  'village': (7, 34),
#  'refuse': (93, 69),
#  'sale': (23, 80),
#  'roll': (96, 44),
#  'communication': (63, 15),
#  'screen': (38, 11),
#  'gain': (13, 62),
#  'resident': (77, 37),
#  'hide': (69, 47),
#  'gold': (93, 38),
#  'club': (4, 59),
#  'farm': (10, 37),
#  'middle': (13, 79),
#  'presence': (99, 82),
#  'district': (42, 93),
#  'shape': (13, 46),
#  'reader': (47, 37),
#  'contract': (58, 59),
#  'crowd': (42, 61),
#  'express': (66, 26),
#  'apartment': (76, 38),
#  'strength': (13, 91),
#  'band': (83, 6),
#  'horse': (29, 60),
#  'target': (54, 43),
#  'prison': (25, 61),
#  'ride': (97, 44),
#  'guard': (91, 18),
#  'reporter': (45, 42),
#  'demand': (10, 60),
#  'deliver': (60, 16),
#  'text': (68, 73),
#  'tool': (61, 43),
#  'vehicle': (64, 96),
#  'observe': (95, 90),
#  'flight': (19, 58),
#  'facility': (57, 40),
#  'understanding': (73, 69),
#  'emerge': (49, 98),
#  'advantage': (41, 45),
#  'leadership': (57, 77),
#  'earn': (77, 19),
#  'pound': (39, 4),
#  'basis': (81, 38),
#  'operate': (59, 17),
#  'guest': (42, 52),
#  'sample': (61, 42),
#  'contribute': (44, 89),
#  'block': (11, 88),
#  'protection': (63, 8),
#  'settle': (92, 91),
#  'feed': (33, 99),
#  'collect': (4, 91),
#  'identity': (19, 63),
#  'title': (43, 29),
#  'lesson': (6, 12),
#  'faith': (63, 28),
#  'river': (85, 27),
#  'promote': (40, 61),
#  'count': (45, 64),
#  'marry': (82, 96),
#  'technique': (6, 94),
#  'path': (32, 87),
#  'ear': (37, 57),
#  'shop': (11, 54),
#  'folk': (22, 78),
#  'principle': (9, 13),
#  'survive': (14, 92),
#  'lift': (51, 39),
#  'border': (66, 46),
#  'competition': (42, 45),
#  'jump': (23, 75),
#  'gather': (40, 74),
#  'limit': (45, 17),
#  'fit': (19, 86),
#  'cry': (9, 18),
#  'equipment': (65, 91),
#  'associate': (19, 64),
#  'critic': (59, 41),
#  'aspect': (56, 95),
#  'insist': (62, 69),
#  'failure': (47, 58),
#  'comment': (57, 65),
#  'affair': (91, 77),
#  'procedure': (7, 96),
#  'spread': (3, 76),
#  'chairman': (64, 37),
#  'baseball': (18, 91),
#  'ignore': (3, 2),
#  'egg': (28, 97),
#  'belief': (17, 66),
#  'demonstrate': (38, 8),
#  'murder': (61, 10),
#  'gift': (81, 72),
#  'religion': (67, 35),
#  'review': (59, 41),
#  'editor': (46, 46),
#  'engage': (38, 19),
#  'coffee': (29, 95),
#  'document': (40, 29),
#  'speed': (11, 86),
#  'cross': (59, 31),
#  'influence': (65, 60),
#  'commit': (17, 79),
#  'threaten': (94, 80),
#  'youth': (1, 11),
#  'wave': (99, 21),
#  'quarter': (19, 4),
#  'background': (26, 5),
#  'deny': (93, 68),
#  'reaction': (67, 61),
#  'suit': (28, 41),
#  'perspective': (76, 69),
#  'blow': (99, 9),
#  'construction': (61, 45),
#  'intelligence': (48, 70),
#  'destroy': (75, 49),
#  'cook': (37, 87),
#  'connection': (10, 7),
#  'burn': (44, 80),
#  'shoe': (30, 11),
#  'neighbor': (88, 32),
#  'grade': (47, 69),
#  'context': (59, 57),
#  'committee': (51, 19),
#  'mistake': (49, 46),
#  'location': (61, 22),
#  'clothe': (31, 44),
#  'dress': (25, 41),
#  'promise': (17, 79),
#  'function': (2, 62),
#  'bone': (53, 37),
#  'extend': (51, 38),
#  'average': (22, 6),
#  'combine': (7, 27),
#  'wine': (20, 47),
#  'voter': (51, 17),
#  'bus': (34, 79),
#  'hell': (2, 43),
#  'remind': (2, 23),
#  'category': (24, 14),
#  'victory': (8, 48),
#  'key': (86, 35),
#  'medicine': (71, 17),
#  'tour': (43, 54),
#  'depend': (39, 32),
#  'photo': (50, 31),
#  'grab': (44, 47),
#  'classroom': (99, 73),
#  'contact': (90, 73),
#  'justice': (68, 66),
#  'participate': (37, 17),
#  'pair': (82, 95),
#  'exercise': (20, 87),
#  'knee': (42, 19),
#  'flower': (28, 31),
#  'tape': (40, 37),
#  'hire': (40, 13),
#  'supply': (66, 10),
#  'actor': (87, 7),
#  'birth': (3, 58),
#  'search': (65, 4),
#  'tie': (29, 40),
#  'democracy': (49, 16),
#  'circle': (69, 73),
#  'device': (62, 90),
#  'progress': (84, 35),
#  'front': (84, 38),
#  'bottom': (9, 78),
#  'island': (79, 26),
#  'exchange': (12, 52),
#  'studio': (50, 31),
#  'train': (34, 79),
#  'lady': (54, 79),
#  'colleague': (1, 93),
#  'application': (2, 63),
#  'lean': (20, 69),
#  'neck': (29, 40),
#  'damage': (75, 50),
#  'plastic': (31, 37),
#  'plate': (74, 79),
#  'hate': (63, 57),
#  'expression': (48, 89),
#  'football': (18, 69),
#  'theater': (56, 22),
#  'intend': (28, 88),
#  'chicken': (14, 51),
#  'army': (90, 5),
#  'abuse': (5, 0),
#  'shut': (72, 48),
#  'map': (75, 87),
#  'session': (5, 68),
#  'danger': (94, 80),
#  'literature': (12, 27),
#  'rain': (87, 21),
#  'desire': (38, 29),
#  'assessment': (37, 4),
#  'injury': (47, 32),
#  'respect': (17, 11),
#  'nod': (52, 94),
#  'fuel': (46, 83),
#  'leaf': (28, 31),
#  'direct': (47, 26),
#  'instruction': (40, 25),
#  'pool': (11, 80),
#  'climb': (24, 76),
#  'engine': (13, 85),
#  'salt': (96, 39),
#  'expand': (75, 7),
#  'metal': (99, 40),
#  'fat': (34, 96),
#  'ticket': (8, 60),
#  'disappear': (75, 46),
#  'lip': (34, 12),
#  'lunch': (43, 84),
#  'farmer': (25, 33),
#  'sugar': (18, 29),
#  'planet': (95, 5),
#  'explore': (65, 4),
#  'enemy': (42, 42),
#  'surround': (66, 44),
#  'athlete': (57, 48),
#  'invite': (36, 22),
#  'repeat': (1, 36),
#  'soul': (63, 1),
#  'panel': (12, 23),
#  'instrument': (83, 1),
#  'predict': (81, 92),
#  'weather': (86, 20),
#  'commitment': (69, 6),
#  'pocket': (30, 10),
#  'temperature': (23, 53),
#  'poll': (95, 30),
#  'surprise': (0, 66),
#  'proposal': (22, 24),
#  'consequence': (16, 2),
#  'half': (20, 86),
#  'breath': (16, 73),
#  'sight': (98, 90),
#  'balance': (17, 14),
#  'adopt': (50, 45),
#  'minority': (45, 62),
#  'connect': (10, 7),
#  'teaching': (7, 11),
#  'belong': (0, 45),
#  'aid': (3, 95),
#  'advice': (5, 93),
#  'organize': (4, 25),
#  'photograph': (50, 31),
#  'trail': (17, 34),
#  'novel': (10, 28),
#  'code': (65, 24),
#  'jury': (12, 13),
#  'breast': (82, 56),
#  'human': (19, 86),
#  'acknowledge': (51, 94),
#  'theme': (53, 32),
#  'storm': (78, 71),
#  'union': (2, 66),
#  'desk': (1, 26),
#  'fruit': (21, 48),
#  'conclusion': (16, 79),
#  'shadow': (73, 90),
#  'struggle': (15, 90),
#  'conclude': (16, 79),
#  'dance': (66, 84),
#  'analyst': (37, 5),
#  'regulation': (69, 71),
#  'ring': (67, 76),
#  'shift': (86, 59),
#  'revenue': (42, 98),
#  'locate': (61, 21),
#  'mark': (36, 11),
#  'county': (0, 33),
#  'appearance': (48, 27),
#  'package': (67, 17),
#  'difficulty': (34, 32),
#  'bridge': (58, 30),
#  'recommend': (5, 93),
#  'mail': (0, 22),
#  'generate': (61, 46),
#  'propose': (22, 24),
#  'trend': (6, 78),
#  'visitor': (42, 52),
#  'loan': (75, 15),
#  'investor': (55, 74),
#  'profit': (76, 9),
#  'crew': (86, 11),
#  'accident': (82, 20),
#  'male': (80, 86),
#  'meal': (36, 99),
#  'hearing': (37, 58),
#  'traffic': (74, 83),
#  'muscle': (20, 87),
#  'notion': (8, 14),
#  'capture': (22, 60),
#  'prefer': (29, 64),
#  'chest': (80, 55),
#  'earth': (94, 3),
#  'cash': (39, 5),
#  'museum': (38, 7),
#  'beauty': (24, 80),
#  'emergency': (0, 68),
#  'link': (39, 35),
#  'stress': (60, 58),
#  'content': (68, 73),
#  'select': (31, 64),
#  'root': (23, 36),
#  'nose': (10, 77),
#  'declare': (60, 63),
#  'appreciate': (51, 10),
#  'bottle': (76, 21),
#  'launch': (98, 89),
#  'file': (80, 7),
#  ...}

# %%
from sklearn.cluster import SpectralClustering
import numpy as np

# %%
data = list(data_pickle.items())
data = [(word, coord[0],coord[1]) for word,coord in data]
pro_data = np.array(data, dtype=object)
pro_data
# Out:
# array([['will', 66, 69],
#        ['time', 61, 11],
#        ['year', 6, 98],
#        ...,
#        ['gaoler', 87, 79],
#        ['carcinoid', 49, 0],
#        ['tonus', 11, 80]], dtype=object)

# %%
X = pro_data[:,[1,2]][:100]

# %%
n_clusters = 10
clustering = SpectralClustering(n_clusters=n_clusters,
                                assign_labels='discretize',
                                random_state=0).fit(X)

# %%
clustering.labels_
# Out:
# array([4, 4, 0, 9, 9, 9, 0, 0, 2, 2, 8, 0, 0, 2, 2, 4, 0, 4, 2, 4, 0, 0,
#        2, 8, 0, 1, 0, 4, 4, 9, 4, 0, 3, 9, 0, 2, 4, 8, 4, 9, 9, 9, 0, 0,
#        9, 0, 0, 4, 0, 4, 8, 9, 3, 4, 3, 6, 9, 0, 0, 3, 4, 0, 9, 4, 4, 2,
#        4, 4, 0, 0, 2, 2, 0, 4, 0, 9, 4, 6, 4, 9, 4, 0, 4, 2, 4, 0, 4, 2,
#        0, 0, 0, 2, 9, 0, 4, 1, 9, 0, 4, 0])

# %%
# list of foreground names
# foreground_names = ['foreground name1', ...]
clustered_text = dict()
for i in range(10):
    clustered_text[i] =[pro_data[j][0] for j in range(len(clustering.labels_)) if clustering.labels_[j]==i]
clustered_text
# Out:
# {0: ['year',
#   'find',
#   'thing',
#   'work',
#   'call',
#   'family',
#   'country',
#   'help',
#   'problem',
#   'hand',
#   'system',
#   'question',
#   'hold',
#   'bring',
#   'water',
#   'room',
#   'mother',
#   'eye',
#   'job',
#   'issue',
#   'friend',
#   'father',
#   'hour',
#   'stand',
#   'city',
#   'community',
#   'change',
#   'team',
#   'minute',
#   'lead',
#   'parent',
#   'create'],
#  1: ['start', 'watch'],
#  2: ['woman',
#   'life',
#   'school',
#   'feel',
#   'student',
#   'talk',
#   'play',
#   'house',
#   'sit',
#   'power',
#   'continue',
#   'learn',
#   'idea'],
#  3: ['program', 'fact', 'lot', 'word'],
#  4: ['will',
#   'time',
#   'state',
#   'leave',
#   'group',
#   'place',
#   'case',
#   'company',
#   'government',
#   'move',
#   'write',
#   'area',
#   'month',
#   'business',
#   'kind',
#   'head',
#   'provide',
#   'service',
#   'game',
#   'member',
#   'law',
#   'car',
#   'include',
#   'set',
#   'president',
#   'understand',
#   'face'],
#  5: [],
#  6: ['study', 'pay'],
#  7: [],
#  8: ['child', 'turn', 'number', 'money'],
#  9: ['people',
#   'day',
#   'man',
#   'week',
#   'hear',
#   'night',
#   'live',
#   'point',
#   'happen',
#   'story',
#   'book',
#   'side',
#   'lose',
#   'meet',
#   'body',
#   'follow']}

# %%
# texts is the dictionary with all source texts that will be preprocessed
# texts = {'foreground name1': [source text1, source text2, ...], ...}
texts = dict()

foreground_names = []

for i in range(n_clusters):
    if len(clustered_text[i]) > 0:
        foreground_name = 'Label ' + str(i)
        texts[foreground_name] = clustered_text[i]
        foreground_names.append(foreground_name)

# %%
obj = Thesaurus(lang='eng')
# Out:
# [nltk_data] Downloading package words to /home/karam/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/karam/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
obj.set_spacy_model()
# Out:
# /home/karam/Documents/workspace/lib/python3.9/site-packages/spacy/util.py:833: UserWarning: [W095] Model 'en_core_web_md' (3.0.0) was trained with spaCy v3.0 and may not be 100% compatible with the current version (3.2.4). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
# dictionary with the embeddings and tokens of each foreground unit
# processed_foregrounds = {'foreground_name1': {'embeds': embeddings, 'words': tokens}, ...}
processed_foregrounds = obj.process_foreground(foreground_names, texts)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#  12%|█▎        | 4/32 [00:00<00:00, 36.06it/s]
#  28%|██▊       | 9/32 [00:00<00:00, 42.55it/s]
#  44%|████▍     | 14/32 [00:00<00:00, 45.21it/s]
#  59%|█████▉    | 19/32 [00:00<00:00, 45.31it/s]
#  75%|███████▌  | 24/32 [00:00<00:00, 45.28it/s]
# 100%|██████████| 32/32 [00:00<00:00, 44.12it/s]
#  12%|█▎        | 1/8 [00:00<00:05,  1.37it/s]
# 100%|██████████| 2/2 [00:00<00:00, 41.07it/s]
#
#   0%|          | 0/13 [00:00<?, ?it/s]
#  38%|███▊      | 5/13 [00:00<00:00, 45.92it/s]
# 100%|██████████| 13/13 [00:00<00:00, 42.68it/s]
#  38%|███▊      | 3/8 [00:01<00:01,  3.10it/s]
# 100%|██████████| 4/4 [00:00<00:00, 41.07it/s]
#  50%|█████     | 4/8 [00:01<00:00,  4.08it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
#  19%|█▊        | 5/27 [00:00<00:00, 47.97it/s]
#  37%|███▋      | 10/27 [00:00<00:00, 48.36it/s]
#  56%|█████▌    | 15/27 [00:00<00:00, 47.60it/s]
#  74%|███████▍  | 20/27 [00:00<00:00, 47.75it/s]
# 100%|██████████| 27/27 [00:00<00:00, 46.59it/s]
#  62%|██████▎   | 5/8 [00:01<00:01,  2.80it/s]
# 100%|██████████| 2/2 [00:00<00:00, 46.86it/s]
#
# 100%|██████████| 4/4 [00:00<00:00, 48.84it/s]
#  88%|████████▊ | 7/8 [00:01<00:00,  4.65it/s]
#   0%|          | 0/16 [00:00<?, ?it/s]
#  38%|███▊      | 6/16 [00:00<00:00, 50.35it/s]
# 100%|██████████| 16/16 [00:00<00:00, 49.29it/s]
# 100%|██████████| 8/8 [00:02<00:00,  3.59it/s]

# %%
background_embeds, background_words = obj.import_background()

# %%
obj.set_som()

# %%
print("Go to https://nbviewer.org/github/DinarZayahov/thesaurus/blob/master/ThesaurusVisualization.ipynb to see the outputs of the notebook as the GitHub doesn't render dynamic output")
obj.show_map(background_embeds, background_words, foreground_names, processed_foregrounds)
# Out:
# Go to https://nbviewer.org/github/DinarZayahov/thesaurus/blob/master/ThesaurusVisualization.ipynb to see the outputs of the notebook as the GitHub doesn't render dynamic output
#   <div class="bk-root" id="3be4da03-c409-4d94-b4b4-d05c793f67ff" data-root-id="1002"></div>
